# %% [markdown]
# # 0. Imports

# %% [markdown]
# ## 0.1. Libraries

# %%
# data manipulation
from pyspark.sql import SparkSession

# data visualization
from matplotlib import pyplot as plt
import seaborn as sns

# other
from IPython.display import Image

# %% [markdown]
# ## 0.2. Data acquisition

# %%
MAX_MEMORY = '6g'

# instantiate spark session object
spark = SparkSession.builder \
                    .master('local[*]') \
                    .config('spark.local.dir', '/tmp') \
                    .config('spark.submit.deployMode', 'client') \
                    .config('spark.executor.instances', '16') \
                    .config('spark.driver.memory', MAX_MEMORY) \
                    .config('spark.executor.memory', MAX_MEMORY) \
                    .config('spark.executor.memoryOverhead', MAX_MEMORY) \
                    .config('spark.sql.debug.maxToStringFields', '100') \
                    .appName('airbnb-first-booking-prediction') \
                    .getOrCreate()
# Out:
# 22/06/05 12:13:34 WARN Utils: Your hostname, endeavour resolves to a loopback address: 127.0.1.1; using 192.168.0.17 instead (on interface enp3s0)
# 22/06/05 12:13:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark-3.2.1-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/06/05 12:13:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/06/05 12:13:35 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 22/06/05 12:13:36 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# read checkpoint dataset
df = spark.read.parquet('../data/interim/processed')

# %%
# check features and data types
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- signup_method: string (nullable = true)
#  |-- signup_flow: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- affiliate_channel: string (nullable = true)
#  |-- affiliate_provider: string (nullable = true)
#  |-- first_affiliate_tracked: string (nullable = true)
#  |-- signup_app: string (nullable = true)
#  |-- first_device_type: string (nullable = true)
#  |-- first_browser: string (nullable = true)
#  |-- country_destination: string (nullable = true)
#  |-- action: string (nullable = true)
#  |-- action_type: string (nullable = true)
#  |-- action_detail: string (nullable = true)
#  |-- device_type: string (nullable = true)
#  |-- secs_elapsed: float (nullable = true)
#  |-- year_account_created: string (nullable = true)
#  |-- month_account_created: string (nullable = true)
#  |-- week_of_year_account_created: integer (nullable = true)
#  |-- day_of_week_account_created: integer (nullable = true)
#  |-- day_account_created: string (nullable = true)
#  |-- timestamp_first_active_year: string (nullable = true)
#  |-- timestamp_first_active_month: string (nullable = true)
#  |-- timestamp_first_active_week_of_year: integer (nullable = true)
#  |-- timestamp_first_active_day_of_week: integer (nullable = true)
#  |-- timestamp_first_active_day: string (nullable = true)
#  |-- year_first_booking: string (nullable = true)
#  |-- month_first_booking: string (nullable = true)
#  |-- week_of_year_first_booking: integer (nullable = true)
#  |-- day_of_week_first_booking: integer (nullable = true)
#  |-- day_first_booking: string (nullable = true)

# %% [markdown]
# # 1. Exploratory data analysis

# %%
# create temporary table
df.createOrReplaceTempView('dataset')

# %% [markdown]
# ## 1.2. Bivariate analysis

# %% [markdown]
# ### Problem mind map

# %%
Image('../reports/figures/mind-map.png')

# %% [markdown]
# ### Hypotheses list

# %% [markdown]
# ### 1.2.1. Hypothesis 01

# %%
aux = spark.sql('''
        SELECT *
        FROM dataset
        LIMIT 10
''').show()

# %% [markdown]
# ### 1.2.2. Hypothesis 02

# %% [markdown]
# ### 1.2.3. Hypothesis 03

# %% [markdown]
# ### 1.2.4. Hypothesis 04

# %% [markdown]
# ### 1.2.5. Hypothesis 05

# %% [markdown]
# ## 1.3. Multivariate analysis

# %% [markdown]
# ### 1.3.1. Numerical variables

# %% [markdown]
# ### 1.3.2. Categorical variables
